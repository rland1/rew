# %%
# Import Splinter, BeautifulSoup, and Pandas
from splinter import Browser
from bs4 import BeautifulSoup as soup
import pandas as pd
import requests 
from webdriver_manager.chrome import ChromeDriverManager

# %%
# Set the executable path and initialize Splinter
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 93.0.4577
# Get LATEST driver version for 93.0.4577
# Driver [/Users/rachelland/.wdm/drivers/chromedriver/mac64/93.0.4577.63/chromedriver] found in cache

# %%
# Visit the mars nasa news site
url = 'https://www.rew.ca/properties/areas/ucluelet-bc'
browser.visit(url)

# %%
# Convert the browser html to a soup object and then quit the browser
html = browser.html
news_soup = soup(html, 'html.parser')

# %%
news_soup
# Out:
# <html class="geolocation placeholder" data-locale="en-CA"><head><script src="https://www.googletagservices.com/activeview/js/current/osd.js"></script><script async="" src="https://www.google-analytics.com/plugins/ua/linkid.js" type="text/javascript"></script><script async="" src="https://secure.adnxs.com/jpt?callback=districtmHeader.ssp.appnexus.handleAppNexusCallback&amp;callback_uid=VZNd5NE6MFhM0tmT5ieZmDoxiBOG7X~452~gpt-ad-listings-ad-slot-3&amp;psa=0&amp;zone=452&amp;id=15627358&amp;member_id=1908&amp;size=300x250&amp;referrer=https://www.rew.ca/properties/areas/ucluelet-bc" type="text/javascript"></script><script async="" src="https://secure.adnxs.com/jpt?callback=districtmHeader.ssp.appnexus.handleAppNexusCallback&amp;callback_uid=4YlqhjeItgC03Dh6z350ulE9qfoAp3~451~gpt-ad-listings-ad-slot-2&amp;psa=0&amp;zone=451&amp;id=15627357&amp;member_id=1908&amp;size=300x250&amp;referrer=https://www.rew.ca/properties/areas/ucluelet-bc" type="text/javascript"></script><script async="" src=
# ...

# %%
title = news_soup.find('h1', class_= 'searchheader-title')
title
# Out:
# <h1 class="searchheader-title">
# Ucluelet Homes for Sale &amp; MLS® Listings
# </h1>

# %%
for listing_paragraph in news_soup.select('.displaypanel-body'):
	try:
		print('**********')
		#print(listing_paragraph)
		print(listing_paragraph.select('div', class_= 'displaypanel-title hidden-xs'))

	except Exception as e:
		#raise e
		print('')
# Out:
# **********
#
# **********
#
# **********
#
# **********
#
# **********
#
# **********
#
# **********
#
# **********
#
# **********
#
# **********
#
# **********
#
# **********
#
# **********
#
# **********
#
# **********
#
# **********
#
# **********
#
# **********
#
# **********
#
# **********
